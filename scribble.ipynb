# %%
import requests
import pandas as pd
import pprint

# %% [markdown]
# ## Notizen
# - Metadaten nicht mit ausgeben, zB Pagination
# - items per page maximal 1000, falls Probleme datenguide feedback geben
# - Schemainformationen können über das schlagwort introspection bei graphql abgerufen werden
# - @include/@skip funktioniert serverside (with fixed true false)
# - variables work in principle as well! This might simplify Query building
# - (graphene is a python framework for building graphQl servers)
#
# ## OP
# 1. Automatic pagination
# 1. region explorer wäre schoen (14k) regions
# 1. Sind Fragments nützlich?
# 1. Sind inline framgemes nuetzlich ".. on 'DataType'" -> Nützlich bein verschiedenen implementierungen
# von einem type interface. Haben wir das?
# 1. nuts ebenen 1,2,3 sind viel weniger werte als kein nuts filter

# %%
time_series = """
              {
  region(id:"05911") {
    id
    name
    	BEVMK3 {
    value
    year
    }
  }
}              
"""

# %%
join_example = """
{
  allRegions(page: 0, itemsPerPage: 10) {
    regions(parent: "10", nuts: 3) {
      id
      name
      BEVSTD(year: 2017){
        value
        year
      }
      WAHL09(year: 2017, PART04: B90_GRUENE) {
        value
        year
        PART04
      }
    }
    page
    itemsPerPage
    total
  }
}
"""

# %%
def runQuery(queryString):
    post_json = dict()
    post_json["query"] = queryString
    header = { 'Content-Type': 'application/json' }
    URL = "https://api-next.datengui.de/graphql"
    resp = requests.post(url=URL,headers=header,json=post_json)
    
    if resp.status_code == 200:
        return resp.json()
    else:
        raise Exception(f"Http error: status code {resp.status_code}")

# %%
result = runQuery(time_series)
result
# Out:
# {'data': {'region': {'id': '05911',
#    'name': 'Bochum',
#    'BEVMK3': [{'value': 662, 'year': 2011},
#     {'value': 634, 'year': 2012},
#     {'value': 583, 'year': 2013},
#     {'value': 632, 'year': 2014},
#     {'value': 625, 'year': 2015},
#     {'value': 556, 'year': 2016}]}}}

# %%
# Query Transformation

def countDataFrames(dic):
    n_dfs = 0
    for value in dic.values():
        if type(value) == pd.DataFrame:
            n_dfs += 1
    return n_dfs
            
def findDataFrame(dic):
    for (key,value) in dic.items():
        if type(value) == pd.DataFrame:
            return value
        
def addDictScalarsToDf(dic,df):
    for (key,value) in dic.items():
        if type(value) != pd.DataFrame:
            df[key] = value
        else:
            df = df.rename(columns = {'value':key})
    return df
            
def dicToDf(dic):
    n_df = countDataFrames(dic)
    if n_df == 0:
        return pd.DataFrame(dic,index=[0])
    else:
        df = findDataFrame(dic)
        return addDictScalarsToDf(dic,df)
            
            
def convertHirachy(hierachy):
    new_dic = dict()
    for key,value in hierachy.items():
        if type(value) == dict:
            new_dic[key] = convertHirachy(value)
        elif type(value) == list:
            new_dic[key] = pd.concat(list(map(convertHirachy,value)))
        else:
            new_dic[key] = value
            
    return dicToDf(new_dic)

# %%
desc_query = """
{
  __type(name: "Region") {
    fields {
      name
      description
    }
  }
}
"""

long_descriptions = convertHirachy(runQuery(desc_query)).assign(short_descr = lambda df: df.description.str.extract('\*\*([^*]*)\*\*'))

# %%
def get_long_descriptions(df):
    cols = df.columns

# %%
x = convertHirachy(result)
reversed_cols = list(reversed(list(x.columns)))
x.loc[:,reversed_cols]
# Out:
#      name     id  year  BEVMK3
# 0  Bochum  05911  2011     662
# 0  Bochum  05911  2012     634
# 0  Bochum  05911  2013     583
# 0  Bochum  05911  2014     632
# 0  Bochum  05911  2015     625
# 0  Bochum  05911  2016     556

# %%
pagination_example ="""
{
  allRegions(page: 0, itemsPerPage: 10) {
    regions(parent: "09", nuts: 3) {
      id
      name
      WAHL09(year: 2017, PART04: B90_GRUENE) {
        value
        year
        PART04
      }
    }
    page
    itemsPerPage
    total
  }
}
"""

# %%
variable_and_inclusion_example ={
  "query": """
query foo ($x :String!,$includeSource : Boolean = false)       {
  region(id:$x) {
    id
    name
    	BEVMK3 {
    value
    year
    source @include(if: $includeSource) {
      name
      url
    }
    }
  }
}              
"""
,
  "operationName": "foo",
   "variables": { "x": "01" ,
                "includeSource" : False}
}

# %%
# Q2['variables']['region'] = "09"
pprint.pprint(requests.post(url="https://api-next.datengui.de/graphql",json=variable_and_inclusion_example).json())
# Out:
# {'data': {'region': {'BEVMK3': [{'value': 6049, 'year': 2011},
#                                 {'value': 5678, 'year': 2012},
#                                 {'value': 5288, 'year': 2013},
#                                 {'value': 5361, 'year': 2014},
#                                 {'value': 4927, 'year': 2015},
#                                 {'value': 5023, 'year': 2016}],
#                      'id': '01',
#                      'name': 'Schleswig-Holstein'}}}

# %%
results = runQuery(Q)
results
# Out:
# {'data': {'allRegions': {'regions': [{'id': '09161',
#      'name': 'Ingolstadt',
#      'WAHL09': [{'value': 5615, 'year': 2017, 'PART04': 'B90_GRUENE'}]},
#     {'id': '09162',
#      'name': 'München',
#      'WAHL09': [{'value': 124365, 'year': 2017, 'PART04': 'B90_GRUENE'}]},
#     {'id': '09163',
#      'name': 'Rosenheim',
#      'WAHL09': [{'value': 3482, 'year': 2017, 'PART04': 'B90_GRUENE'}]},
#     {'id': '09171',
#      'name': 'Altötting',
#      'WAHL09': [{'value': 4182, 'year': 2017, 'PART04': 'B90_GRUENE'}]},
#     {'id': '09172',
#      'name': 'Berchtesgadener Land',
#      'WAHL09': [{'value': 4652, 'year': 2017, 'PART04': 'B90_GRUENE'}]},
#     {'id': '09173',
#      'name': 'Bad Tölz-Wolfratshausen',
#      'WAHL09': [{'value': 7685, 'year': 2017, 'PART04': 'B90_GRUENE'}]},
#     {'id': '09174',
#      'name': 'Dachau',
#      'WAHL09': [{'value': 8163, 'year': 2017, 'PART04': 'B90_GRUENE'}]},
#     {'id': '09175',
#      'name': 'Ebersberg',
#      'WAHL09': [{'value': 10316, 'year': 2017, 'PART04': 'B90_GRUENE'}]},
#     {'id': '09176',
#      'name': 'Eichstätt',
#      'WAHL09': [{'value': 5270, 'year': 2017, 'PART04': 'B90_GRUENE'}]},
#     {'id': '09177',
#      'name': 'Erding',
#      'WAHL09': [{'value': 7452, 'year': 2017, 'PART04': 'B90_GRUENE'}]}],
#    'page': 0,
#    'itemsPerPage': 10,
#    'total': 96}}}

# %%
convertHirachy(results)
# Out:
#    WAHL09  year      PART04     id                     name  page  \
# 0    5615  2017  B90_GRUENE  09161               Ingolstadt     0
# 0  124365  2017  B90_GRUENE  09162                  München     0
# 0    3482  2017  B90_GRUENE  09163                Rosenheim     0
# 0    4182  2017  B90_GRUENE  09171                Altötting     0
# 0    4652  2017  B90_GRUENE  09172     Berchtesgadener Land     0
# 0    7685  2017  B90_GRUENE  09173  Bad Tölz-Wolfratshausen     0
# 0    8163  2017  B90_GRUENE  09174                   Dachau     0
# 0   10316  2017  B90_GRUENE  09175                Ebersberg     0
# 0    5270  2017  B90_GRUENE  09176                Eichstätt     0
# 0    7452  2017  B90_GRUENE  09177                   Erding     0
#
#    itemsPerPage  total
# 0            10     96
# 0            10     96
# 0            10     96
# 0            10     96
# 0            10     96
# 0            10     96
# 0            10     96
# 0            10     96
# 0            10     96
# 0            10     96

# %% [markdown]
# Descriptions

# %%
long_descriptions = convertHirachy(runQuery(desc_query)).assign(short_descr = lambda df: df.description.str.extract('\*\*([^*]*)\*\*'))
# Out:
#       name                                        description  \
# 0       id                                  Regionalschlüssel
# 0     name                                               Name
# 0   AENW01  **Entsorgte/behandelte Abfallmenge a.d. eig. B...
# 0   AENW02    **Abgelagerte Abfallmenge in Deponien**\n  *...
# 0   AENW03  **Entsorg.u.Behandlungsanl.(o.Sortier.u.Zerleg...
# 0   AENW04  **Entsorgte/behandelte Abfallmenge a.d. eig. B...
# 0   AENW05    **Abgelagerte Abfallmenge in Deponien**\n  *...
# 0   AENW06    **Entsorg.u.Behandlungsanl.(o.Sortier.u.Zerl...
# 0   AEW001    **Entsorgungs- und Behandlungsanlagen**\n  *...
# 0   AEW002  **Entsorgte/behandelte Abfallmenge**\n*aus GEN...
# 0   AEW003  **Abgegebene Abfallmenge**\n*aus GENESIS-Stati...
# 0   AEW006    **Erzeuger von primär nachgewiesenen Abfallm...
# 0   AEW007  **Abgegebene Abfallmenge an Entsorger**\n*aus ...
# 0   AEW008    **Entsorgungs- und Behandlungsanlagen**\n  *...
# 0   AEW009  **Aufkommen an Haushaltsabfällen (oh.Elektroal...
# 0   AEW010  **Abgegebene Abfallmenge**\n*aus GENESIS-Stati...
# 0   AEWN09  **Entsorgte/behandelte Abfallmenge**\n*aus GEN...
# 0   AI_Z01  **Durchschnittsalter Gesamtbevölkerung**\n*aus...
# 0   AI_Z02  **Durchschnittsalter weibliche Bevölkerung**\n...
# 0   AI_Z03  **Durchschnittsalter männliche Bevölkerung**\n...
# 0   AI_Z04  **Anteil Personen mit MHG an der Gesamtbevölke...
# 0   AI_Z05  **Anteil Personen mit MHG 0 bis 19 Jahre**\n*a...
# 0   AI_Z06  **Anteil Personen mit MHG 20 bis 59 Jahre**\n*...
# 0   AI_Z07  **Anteil Personen mit MHG 60 Jahre und älter**...
# 0   AI_Z08  **Erwerbslosenquote**\n*aus GENESIS-Statistik ...
# 0   AI_Z09  **Erwerbstätigenquote**\n*aus GENESIS-Statisti...
# 0   AI_Z10  **Erwerbstätigenquote Frauen**\n*aus GENESIS-S...
# 0   AI_Z11  **Erwerbstätigenquote Männer**\n*aus GENESIS-S...
# 0   AI_Z12  **Durchschnittliche Haushaltsgröße**\n*aus GEN...
# 0   AI_Z13  **Anteil Einpersonenhaushalte**\n*aus GENESIS-...
# ..     ...                                                ...
# 0   WAHLSR  **Wahlbeteiligung**\n*aus GENESIS-Statistik "A...
# 0   WAS001    **Wasseraufkommen**\n  *aus GENESIS-Statisti...
# 0   WAS002  **Wasserversorgungsunternehmen**\n*aus GENESIS...
# 0   WAS003  **Wassergewinnungsanlagen**\n*aus GENESIS-Stat...
# 0   WAS004    **Wassergewinnung**\n  *aus GENESIS-Statisti...
# 0   WAS005    **Einw. m. Anschl. an d. öffentl. Wasservers...
# 0   WAS006    **Hausbrunnen oder Quellen mit Trinkwasserge...
# 0   WAS007    **Wasserabgabe an Letztverbraucher**\n  *aus...
# 0   WAS008  **Wasserabgabe je Einwohner und Tag (in Liter)...
# 0   WASNW0    **häusliches und betriebliches Schmutzwasser...
# 0   WASNW2    **genutztes Wasser**\n  *aus GENESIS-Statist...
# 0   WASNW3  **Abwasser**\n*aus GENESIS-Statistik "Erhebung...
# 0   WASNW4    **Trockenmasse des entsorgten Klärschlamms**...
# 0   WASNW5    **Angeschloss. Ew-Werte: dar. angeschloss. E...
# 0   WASNW6    **Jahresabwassermenge**\n  *aus GENESIS-Stat...
# 0   WASNW7    **Angeschlossene Einwohnerwerte (Ew-Werte)**...
# 0   WASNW8    **Abwasserbehandlungsanlagen**\n  *aus GENES...
# 0   WASNW9    **Länge des Kanalnetzes**\n  *aus GENESIS-St...
# 0   WGS001  **Haushalte mit allgemeinem Wohngeld**\n*aus G...
# 0   WGS003    **Durchschn.mtl.Anspruch an allgemeinem Wohn...
# 0   WGS011  **Haushalte mit allgemeinem Wohngeld**\n*aus G...
# 0   WGS031    **Durchschn.mtl.Anspruch an allgemeinem Wohn...
# 0   WOGWZ1    **Wohnungen in Gebäuden mit Wohnraum**\n  *a...
# 0   WOH016    **Wohnungen in neuen Nichtwohngebäuden**\n  ...
# 0   WOHN01    **Wohnungen**\n  *aus GENESIS-Statistik "For...
# 0   WOHN02    **Wohnungen**\n  *aus GENESIS-Statistik "Sta...
# 0   WOHN03    **Wohnungen in Wohngebäuden**\n  *aus GENESI...
# 0   WOHN04    **Wohnungen in Wohngebäuden (ohne Wohnheime)...
# 0   WOHNGB    **Wohngebäude**\n  *aus GENESIS-Statistik "G...
# 0   WOHNY1    **Wohnungen in Wohn- und Nichtwohngebäuden**...
#
#                                           short_descr
# 0                                                 NaN
# 0                                                 NaN
# 0       Entsorgte/behandelte Abfallmenge a.d. eig. BL
# 0                 Abgelagerte Abfallmenge in Deponien
# 0     Entsorg.u.Behandlungsanl.(o.Sortier.u.Zerlege.)
# 0       Entsorgte/behandelte Abfallmenge a.d. eig. BL
# 0                 Abgelagerte Abfallmenge in Deponien
# 0     Entsorg.u.Behandlungsanl.(o.Sortier.u.Zerlege.)
# 0                 Entsorgungs- und Behandlungsanlagen
# 0                    Entsorgte/behandelte Abfallmenge
# 0                              Abgegebene Abfallmenge
# 0     Erzeuger von primär nachgewiesenen Abfallmengen
# 0                 Abgegebene Abfallmenge an Entsorger
# 0                 Entsorgungs- und Behandlungsanlagen
# 0   Aufkommen an Haushaltsabfällen (oh.Elektroaltg...
# 0                              Abgegebene Abfallmenge
# 0                    Entsorgte/behandelte Abfallmenge
# 0                Durchschnittsalter Gesamtbevölkerung
# 0            Durchschnittsalter weibliche Bevölkerung
# 0            Durchschnittsalter männliche Bevölkerung
# 0    Anteil Personen mit MHG an der Gesamtbevölkerung
# 0              Anteil Personen mit MHG 0 bis 19 Jahre
# 0             Anteil Personen mit MHG 20 bis 59 Jahre
# 0          Anteil Personen mit MHG 60 Jahre und älter
# 0                                   Erwerbslosenquote
# 0                                 Erwerbstätigenquote
# 0                          Erwerbstätigenquote Frauen
# 0                          Erwerbstätigenquote Männer
# 0                    Durchschnittliche Haushaltsgröße
# 0                         Anteil Einpersonenhaushalte
# ..                                                ...
# 0                                     Wahlbeteiligung
# 0                                     Wasseraufkommen
# 0                        Wasserversorgungsunternehmen
# 0                             Wassergewinnungsanlagen
# 0                                     Wassergewinnung
# 0    Einw. m. Anschl. an d. öffentl. Wasserversorgung
# 0   Hausbrunnen oder Quellen mit Trinkwassergewinnung
# 0                    Wasserabgabe an Letztverbraucher
# 0        Wasserabgabe je Einwohner und Tag (in Liter)
# 0          häusliches und betriebliches Schmutzwasser
# 0                                    genutztes Wasser
# 0                                            Abwasser
# 0            Trockenmasse des entsorgten Klärschlamms
# 0   Angeschloss. Ew-Werte: dar. angeschloss. Einwo...
# 0                                 Jahresabwassermenge
# 0            Angeschlossene Einwohnerwerte (Ew-Werte)
# 0                          Abwasserbehandlungsanlagen
# 0                               Länge des Kanalnetzes
# 0                  Haushalte mit allgemeinem Wohngeld
# 0      Durchschn.mtl.Anspruch an allgemeinem Wohngeld
# 0                  Haushalte mit allgemeinem Wohngeld
# 0      Durchschn.mtl.Anspruch an allgemeinem Wohngeld
# 0                  Wohnungen in Gebäuden mit Wohnraum
# 0                Wohnungen in neuen Nichtwohngebäuden
# 0                                           Wohnungen
# 0                                           Wohnungen
# 0                           Wohnungen in Wohngebäuden
# 0          Wohnungen in Wohngebäuden (ohne Wohnheime)
# 0                                         Wohngebäude
# 0            Wohnungen in Wohn- und Nichtwohngebäuden
#
# [475 rows x 3 columns]

# %%
allArgs = """{
  __type(name: "Region") {
    fields {
      name
      args {
        description
        defaultValue
        type {
          ofType {
            name
          }
        }
        }
      }
    }
}"""

# %%
all_args= runQuery(allArgs)

# %%
#region hat 475 argumente
len(all_args['data']['__type']['fields'])
# Out:
# 475

# %% [markdown]
# ## Hacks

# %%
#Select all by filtering not in empty

query = """
{
  region(id:"05911") {
    id
    name
    	BEVSTD(filter: { ALTX20: { nin: []}}) {
    value
    ALTX20
    year
    }
  }
}      
""";

# %%
{
  __type(name: "GES") {
    name
		enumValues {
		  description
		  deprecationReason
		}
  }
}

# %%
{
  __type(name: "Region") {
    name
    fields {
      name
      description
      type {
        name
        kind
      }
    }
  }
}

# %%
##Fragment syntax

{
  allRegions(page: 0, itemsPerPage: 10) {
    regions(parent: "10", nuts: 3) {
      id
      name
      BEVSTD(year: 2017){
        value
        year
      }
      WAHL09 (year: 2017, PART04: B90_GRUENE) {
				...foo
      }
    }
    page
    itemsPerPage
    total
  }
}

fragment foo on WAHL09 {
        value
        year
        PART04
      }
